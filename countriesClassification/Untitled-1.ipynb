# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.impute import KNNImputer
import matplotlib.pyplot as pl

# %%
# HDI
df_HDI = pd.read_csv('data/human-development-index-vs-gdp-per-capita.csv')
df_HDI.drop(columns=df_HDI.columns[-1], axis=1, inplace=True)


df_HDI = df_HDI[['Entity', 'Year', 'Human Development Index']]
df_HDI = df_HDI.pivot(index='Entity', columns='Year').reset_index()
df_HDI.columns = df_HDI.columns.get_level_values(1)
df_HDI = df_HDI.rename(columns={'':'Countries'})


l = [x for x in range(1990, 2022, 1)]
l = l.insert(0, 'Countries')


df_HDI[l]


# df_HDI.to_csv(r'C:\Users\pc\Desktop\countries\countries classifiers v2\countriesClassification\data\HDI.csv')
# df_HDI.drop(['Year'], axis=1)
# df_HDI = df_HDI.set_index('Year')
# df_HDI.groupby(by=['Year', 'Entity']).rank()
# df_HDI = df_HDI.T
# df_HDI
# l = df_HDI.columns.sort_values()
# df_HDI[l]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 14
#      11 l = [x for x in range(1990, 2022, 1)]
# ...

# %%
df_HDI.set_index(df_HDI['Year'])
# Out:
#            Entity      Code  Year  Human Development Index  \
# Year
# 2015     Abkhazia  OWID_ABK  2015                      NaN
# 1990  Afghanistan       AFG  1990                    0.273
# 1991  Afghanistan       AFG  1991                    0.279
# 1992  Afghanistan       AFG  1992                    0.287
# 1993  Afghanistan       AFG  1993                    0.297
# ...           ...       ...   ...                      ...
# 1985     Zimbabwe       ZWE  1985                      NaN
# 1986     Zimbabwe       ZWE  1986                      NaN
# 1987     Zimbabwe       ZWE  1987                      NaN
# 1988     Zimbabwe       ZWE  1988                      NaN
# 1989     Zimbabwe       ZWE  1989                      NaN
#
#       GDP per capita, PPP (constant 2017 international $)  \
# Year
# 2015                                                NaN
# 1990                                                NaN
# 1991                                                NaN
# ...
