# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df
# Out:
#      Unnamed: 0  log_gdp_percap  inter_gdp_percap  beta_gdp_percap  \
# 0             0       10.413338          6.742368         0.070417
# 1             1        7.404926          5.247520         0.038972
# 2             2        6.626099          4.632852         0.026662
# 3             3        7.487349          4.983592         0.045805
# 4             4        8.006516          5.001866         0.051285
# ..          ...             ...               ...              ...
# 261         261        8.583031          5.380978         0.051436
# 262         262        6.477391          5.872882         0.018600
# 263         263        8.819736          6.584793         0.042445
# 264         264        7.284067          5.534852         0.026082
# 265         265        7.424655          5.846225         0.020999
#
#      r2_gdp_percap       log_gdp  beta_reg_gdp  r2_reg_gdp  avg oil gdp  \
# 0         0.901657  3.544708e+09      0.077589    0.936489     0.000468
# ...
